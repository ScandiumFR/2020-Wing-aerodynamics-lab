# %% [markdown]
# # SESX 2022 - Aerofoil Lab Measurement and Data File

# %% [markdown]
# ### Theoretical Considerations
#
# This section will provide you with the theoretical aspects required to understand the airfoil lab (or the infinite wing lab). The main objective of these experiments is to give you an insight into  two dimensional flow dynamics. First, we must define the operating environment and the operating conditions mainly to be able to create and assess the applicability of the assumptions framework. The operating environment is a low-speed open-loop wind tunnel with 100mm by 50mm cross section. The average temperature is approximately 20-25$^{\circ}$C (you need to take a note of this from the thermometer) and the ambient pressure can be assumed as the standard sea level pressure. The operating conditions are represented by the wind tunnel's speed, which ranges from 10 to 40 m/s. There are two applicable assumptions that will be described separately: \textit{inviscid flow} and \textit{incompressible flow}. These two assumptions will greatly simplify our theoretical model.
#
# #### Inviscid flow
#
# There are no truly inviscid flows in nature as the phenomena of friction (viscosity), mass diffusion and thermal conduction always occur at a molecular level to a certain degree. However, in many engineering applications, these transport phenomena are mostly negligible, especially for high and finite Reynolds numbers flows. Therefore, the flow can be separated into two regions: the inviscid region and the viscous region. In the case of an aerofoil mounted in a flow at a low angle of attack, the viscous region is small and represented by the thin viscous boundary layer neighbouring the surface of the aerofoil. The inviscid region is represented by all the flow outside the boundary layer. **Given a wing chord $c=0.063m$, an upstream flow velocity $u=20 m/s$ and a kinematic viscosity $\nu= 15.11\times10^{-6} m^{2}/s$ ($Re=\frac{u\times c}{\nu}$), how well is this assumption holding? Also, can the flow still be considered inviscid when the aerofoil is at high angles of attack at which separation occurs and hence a large wake is formed downstream?}**
#
# #### Incompressible flow
#
# An incompressible flow is defined as a flow for which the working fluid density $\rho$ is constant. There are, of course, more advanced definitions of what compressibility is which link to thermodynamic considerations, but a good approximation is that all flows for which Mach number (M) is less than 0.3, can be considered incompressible. **Hence, what are your comments regarding the applicability of the incompressibility assumption for the current case?**
#
# #### Bernoulli's Equation
# Using the assumptions of the inviscid and the incompressible flow, Bernoulli's equation becomes applicable. The equation is:
#
# \begin{equation}
# p+\frac{1}{2}\rho u^2=const.
# \label{Eqn:bernoulli1}
# \end{equation}
#
# <h5><center>Equation 1</center></h5>
#
# Thus for an incompressible, inviscid flow, the static and dynamic pressures add up to a constant along streamlines.
#
# #### Irrotational flow
# If we consider an infinitesimal fluid element moving through the flow field, we can describe its orientation as a combination of both translation and rotation. Additionally, the fluid element may also change its shape, but this change can also be considered a combination of translation and rotation. The case on the right of Figure 1 shows on the upper streamline a fluid element where the angular velocities of its sides are zero, hence the flow is irrotational. The lower streamline of the case on the right shows a two dimensional fluid element where the angular velocities of the two intersecting sides are finite, but equal and opposite to each other and so their sum is identically zero; hence the flow is irrotational as well. **How well is this assumption holding for the current case? Explain only from a qualitative point of view**
#
# <table style="width:60%">
#
# <td><img src="attachment:irrotational.png" ></td>
# <tr>
# <td> Figure 1 - Rotational and irrotational Flow comparison </td>
#
# </table>
# If besides inviscid and incompressible, the flow is also irrotational, the value of the constant from Equation 1 is the same between all streamlines. Applying Bernoulli's equation far upstream:
#
# \begin{equation}
# p_{\infty}+\frac{1}{2}\rho u_{\infty}^2=p_{0}
# \end{equation}
#
# <h5><center>Equation 2</center></h5>
#
# where $p_{0}$ is defined as the stagnation or total pressure and the subscript $\infty$ refers to the upstream conditions.
#
# #### Pressure coefficient
# The static pressures and velocities around the aerofoil differ from their upstream values. Assuming that there is a negligible variation of static pressure through the thin boundary layers on the surface of the aerofoil, Bernoulli's equation can be applied to relate the surface static pressure $p_{s}$ to the upstream conditions:
#
# \begin{equation}
# p_{0}=p_{s}+\frac{1}{2}\rho u^2=p_{\infty}+\frac{1}{2}\rho u_{\infty}^2
# \label{Eqn:bernoulli3}
# \end{equation}
# <h5><center>Equation 3</center></h5>
#
# where $u$ is the velocity just outside the boundary layer. By defining the surface pressure coefficient, $C_{p}$ in the usual way, from Equation 3:
#
# \begin{equation}
# C_{p}=\frac{p_{s}-p_{atm}}{\frac{1}{2}\rho u_{\infty}^2}=\frac{p_{s}-p_{atm}}{p_{0}-p_{\infty}}
# \label{Eqn:pressurecoeff}
# \end{equation}
# <h4><center>Equation 4</center></h4>
#
# For the airfoil, we will assume the static pressure farther away from the airfoil surface is $P_{atm}$ and the velocity is calculated from the tunnel free stream pressure and total pressure. This will be measured through the use of a manometer, where the pressure is proportional to the column height and the inclination angle of the manometer (FEEG1003 Thermofluids for revision on how to use a manometer).
#
# The experimental setup is fitted with a number of pressure tappings on both the top and bottom surfaces that are connected to a multi-manometer; this will allow you to measure the static pressures at points around the aerofoil. A standard pitot-static probe is mounted at the inlet to the contraction and the inlet of the test section to read the stagnation pressure as well as the freestream static pressure. The coefficients of pressure around the aerofoil can be determined using these readings.
#
# Once you have the pressure coefficents you can integrate them to calcuate lift and drag. Note that the drag you will measure is only the pressure drag and would not include the viscous contribution.
#
# #### Force considerations
# In general terms an aerofoil at a geometric angle of attack $ \alpha$.
#
# <table style="width:80%">
#
# <td><img src="attachment:Aerolab%20lift.png" ></td>
# <tr>
# <td> Figure 2 - Wing dimensions diagram and force considerations across the wing section </td>
#
# </table>
# The objective now is to determine the lift coefficients using the readings provided by the pressure tappings. First, consider an element of unit span and length $\Delta s$ on the surface of the aerofoil (i.e. left small purple line) which is tilted by $\theta$ with respect to the aerofoil's axis (i.e. red line). The normal net force to this element is, under the aforementioned assumptions, $p_{s}\Delta s$ which in the XY Cartesian coordinate system defined by the aerofoil has the following components:
#
# \begin{equation}
# \begin{split}
# & \Delta N_{a}=\pm p_{s}\cos(\theta)\Delta s=\pm p_{s}\Delta x \\
# & \Delta T_{a}=\pm p_{s}\sin(\theta)\Delta s=\pm p_{s}\Delta y
# \label{Eqn:force1}
# \end{split}
# \end{equation}
# <h4><center>Equation 5</center></h4>
#
# The $+$ elements represent the ones which create a force component in positive Y or X direction and $-$ elements represent the ones that create a force component in negative Y or X direction.
#
# The value of the normal force (N) is the integration of all $\Delta N$ across the surface of the entire airfoil. Since in the current case the size of $\Delta s$ is not infinitesimal and has a finite determinable value, the integration becomes a summation of the normal force across the upper and lower surfaces of the airfoil. The same applies to the tangential force. Hence:
#  \begin{equation}
#   \begin{split}
#    N &=\sum_{up} \Delta N_{a}+\sum_{up} \Delta N_{f}+\sum_{low} \Delta N_{a}+\sum_{low} \Delta N_{f}\\
#    T &=\sum_{up} \Delta T_{a}+\sum_{up} \Delta T_{f}+\sum_{low} \Delta T_{a}+\sum_{low} \Delta T_{f}
#   \label{Eqn:force3}
#   \end{split}
#  \end{equation}
#  <h4><center>Equation 6</center></h4>
#
#  where N is the normal force per unit span and T is the tangential force per unit span, both relative to the XY Coordinate system belonging to the aerofoil. The above summation can be re-written as an integral and converted to a force coeffcient as follows:
#
#   \begin{equation}
#    \begin{split}
#     C_{N} &=\frac{N}{\frac{1}{2}\rho u_{\infty}^2 c}=\frac{1}{c} \cdot \int_{0}^{c} (C_{p,l} - C_{p,u}) \cdot dx\\
#     C_{T} &=\frac{T}{\frac{1}{2}\rho u_{\infty}^2 c}=\frac{1}{c} \cdot \int_{0}^{c} (C_{p,u} \cdot \frac{dy_{u}}{dx} - C_{p,l} \cdot \frac{dy_{l}}{dx}) \cdot dx
#    \label{Eqn:force4}
#    \end{split}
#   \end{equation}
# <h4><center>Equation 7</center></h4>
#
# Here $\rho$ is the air density, $u_{\infty}$ is the upstream wind velocity and $c$ is the wing chord. $\frac{dy_{u}}{dx}$ and $\frac{dy_{l}}{dx}$ are slope of the aerofoil surface at the location of the tappings on the upper and lower surfaces.
#
# These normal and tangential forces can be convered to lift and drag coefficients. Note that for very thin airfoils, the pressure drag is basically zero as the slope of the airfoil is very small.Regardless, we can determine the the coefficient of lift that can be determined as,
#
#  \begin{equation}
#       C_{l} =C_{N}\cos(\alpha)-C_{T}\sin(\alpha)
#     \label{Eqn:force5}
#     \end{equation}
#
#    <h4><center>Equation 8</center></h4>
#
# For the above equation, if $\alpha$ is small, then, the normal force and the lift force will be very similar to each other.

# %% [markdown]
# ### Thin aerofoil theory
# The objective of this brief section is to refresh assumptions under which this theory is applicable and also, to refresh some of its consequences. Requirements:
# * As the name states, the maximum aerofoil thickness must be small compared to the chord length. You will be using a NACA0020 airfoil section where the maximum thickness of the wing is approximately 12.6 $mm$ and the chord is 63 $mm$.
# * The theory is restricted to low angles of attack.
# * The flow must be both inviscid and incompressible.
# * The flow must be two-dimensional.
#
# **Given the current experimental conditions, how applicable are these assumptions?**
# This theory predicts the following key points for aerofoils which respect the aforementioned requirements:
# * Lift coefficient is directly proportional with AoA and the proportionality parameter is $2\pi$ (i.e. $\frac{dC_{L}}{d\alpha}=2\pi$).
# * On a symmetric aerofoil - no camber - the centre of pressure is located at the quarter-chord behind LE.
# * For any aerofoil - with or without camber - the aerodynamic centre is located at the quarter-chord behind LE.
#
# Numerically, the coefficient of lift of an aerofoil within the assumptions of thin aerofoil theory is,
#
#   \begin{equation}
#        C_{l}==2\pi(\alpha-\alpha_{0})
#       \label{Eqn:thinaerofoil1}
#      \end{equation}
# <h4><center>Equation 9</center></h4>
#
# where $\alpha_{0}$ represents the angle of attack at zero lift and $\alpha$ represents the \textit{geometric} AoA. The value $2\pi$ is the theoretical lift curve slope and in your experiment coudl give an answer slighty different than this. The value of $\alpha_0$ represents the added effect of the camber on the coefficient of lift. For a symmetric aerofoil, the value of $\alpha_0$ is 0. Furthermore, the value of $\alpha_0$ can be either positive or negative, depending on a positive or negative camber, respectively. You are required to compare the experimental results with the theoretical expectations of the thin aerofoil theory. \\
# Refer to the lecture notes for further details about the theory.

# %% [markdown]
# ## Experiment
#
# The objective of this experiment is to examine the pressure distribution around an aerofoil of effectively infinite span, in order to show the effects of incidence changes and to determine the lift of the aerofoil. The pressure tappings data is to be compared with CFD data which is generated during the CFD lab. Please make sure that you have followed and understood the theoretical background outlined before continuing.

# %% [markdown]
# ## Import required modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import cos
from numpy import sin
import os
import pandas as pd

# %% [markdown]
# ## Required functions

# %%
def Aerofoil(x):
    '''This function takes the x coordinate and returns the positive y coordinate of the aerofoil'''
    t=0.20
    y = (5*t)*((0.2969*x**0.5)-(0.1260*x)-(0.3516*x**2)+(0.2843*x**3)-(0.1015*x**4))
    return(y)

# %% [markdown]
# ## General Data
# Enter the temperature in degrees and the Pressure in Pa in the below cell then enter a formula to calculate the Density which will be required later

# %%
Temperature_deg = 20 #degrees C
Pressure=  102000 #Pa
R = 287.058 #Gas constant

Temperature_kelvin = Temperature_deg + 273.15 #K

# %% [markdown]
# The aerofoil spans the wind tunnel's working section, thus ideally generating a two-dimensional flow. Around the aerofoil, 12 pressure tappings are fitted - small diameter holes (2.5 mm), through a 3D printed aerofoil with tapping tubes connected. These pressure tappings enable the surface static pressure $p_{s}$ to be measured at various stations. Each pressure tube is connected to a manometer. The dynamic pressure, $ q_{\infty}=\frac{1}{2}\rho u_{\infty}^2 $, can be obtained from the pressure difference, $p_{0}-p_{\infty}$, using Equation equation 3. You will read the height of the different tappings and  $P_{\infty}$ is proportional to the difference between the tapping tube height and the atm height. The pressure coefficients at various points on the aerofoil are found using Equation 4. A layout of the pressure tappings can be found below.

# %%
#This is set up so if the aerofoil is turned clockwise the upper surface with have the tapping positons below otherwise
#just switch upper and lower surface around
x = [1, 2, 4.5, 7.5, 11, 14.5, 20, 26, 32.1, 38, 44, 50]
xc_upper= []
xc_lower =[]
for i in range(12):
    if i % 2 == 0:
        xc_lower.append(x[i]/63)
    if i % 2 == 1:
        xc_upper.append(x[i]/63)
        
plt.plot([Aerofoil(i) for i in xc_upper], xc_upper, 'ro', label= 'Upper Surface Tappings')
plt.plot([Aerofoil(i) for i in np.linspace(0,1,100)], np.linspace(0,1,100), 'g-')
plt.plot([-Aerofoil(i) for i in xc_lower], xc_lower, 'bo', label = 'Lower Surface Tappings')
plt.plot([-Aerofoil(i) for i in np.linspace(0,1,100)], np.linspace(0,1,100), 'g-')
plt.gca().invert_yaxis()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid()
plt.axis('scaled')
plt.show()
print(xc_lower, xc_upper)
# Out:
# [0.015873015873015872, 0.07142857142857142, 0.1746031746031746, 0.31746031746031744, 0.5095238095238096, 0.6984126984126984] [0.031746031746031744, 0.11904761904761904, 0.23015873015873015, 0.4126984126984127, 0.6031746031746031, 0.7936507936507936]

# %% [markdown]
# ## Data collection

# %% [markdown]
# ### 0 degrees

# %% [markdown]
# Next with the aerofoil set to 0 degrees then enter the manometer readings which can be used for during data processing. A summary of the data can be seen in the summary table below. When turning the aerofoil clockwise the tappings on the left hand side will be the lower surface and therefore put them on the tappings 1-6 then upper surface will be 7 to 12.

# %%
Total_zerodeg = 235
Static_zerodeg = 183

#The below readings for one left hand side of the foil (if you turn the foil clockwise - this will be lower side)
zerodeg_tapping1 = 206
zerodeg_tapping2 = 154
zerodeg_tapping3 = 145
zerodeg_tapping4 = 149
zerodeg_tapping5 = 182
zerodeg_tapping6 = 167
#The below readings are right hand side of the foil (if you turn the foil clockwise - this will be the upper side)
zerodeg_tapping7 = 177
zerodeg_tapping8 = 142
zerodeg_tapping9 = 146
zerodeg_tapping10 = 155
zerodeg_tapping11 = 163
zerodeg_tapping12 = 174

zerodeg = [Total_zerodeg,Static_zerodeg,zerodeg_tapping1,zerodeg_tapping2,zerodeg_tapping3,zerodeg_tapping4,
           zerodeg_tapping5,zerodeg_tapping6,zerodeg_tapping7,zerodeg_tapping8,zerodeg_tapping9,zerodeg_tapping10,
           zerodeg_tapping11,zerodeg_tapping12]
Index_zero = ['P_tot', 'P_static', 'LWR x/c = 0.0159', 'LWR x/c = 0.0714', 'LWR x/c = 0.175', 'LWR x/c = 0.317',
              'LWR x/c = 0.510','LWR x/c = 0.698','UPPER x/c = 0.0317', 'UPPER x/c = 0.119', 'UPPER x/c = 0.230',
              'UPPER x/c = 0.413', 'UPPER x/c = 0.603', 'UPPER x/c = 0.794']

d = {'Variable': Index_zero,'Manometer Reading (mm)':zerodeg}
df = pd.DataFrame(d)

df.to_csv('Zero_deg.csv', index=False)

# %% [markdown]
# ### 6 degrees

# %% [markdown]
# Next with the aerofoil set to 6 degrees, turning the aerofoil clockwise will result in the upper surface as labelled in the summary table being the upper surface, if turned anti clockwise just switch lower and upper around and adjust general data cell, the lowest numbered tapping is the leading edge. When turning the aerofoil clockwise the tappings on the left hand side will be the lower surface and therefore put them on the tappings 1-6 then upper surface will be 7 to 12.

# %%
Total_sixdeg = 235
Static_sixdeg = 183

#The below readings for one left hand side of the foil (if you turn the foil clockwise - this will be lower side)
sixdeg_tapping1 = 229
sixdeg_tapping2 = 183
sixdeg_tapping3 = 163
sixdeg_tapping4 = 160
sixdeg_tapping5 = 185
sixdeg_tapping6 = 169

#The below readings are right hand side of the foil (if you turn the foil clockwise - this will be the upper side)
sixdeg_tapping7 = 138
sixdeg_tapping8 = 119
sixdeg_tapping9 = 133
sixdeg_tapping10 = 148
sixdeg_tapping11 = 162
sixdeg_tapping12 = 173

sixdeg = [Total_sixdeg,Static_sixdeg,sixdeg_tapping1,sixdeg_tapping2,sixdeg_tapping3,sixdeg_tapping4,sixdeg_tapping5,sixdeg_tapping6,
           sixdeg_tapping7,sixdeg_tapping8,sixdeg_tapping9,sixdeg_tapping10,sixdeg_tapping11,sixdeg_tapping12]
Index_six = ['P_tot', 'P_static', 'LWR x/c = 0.0159', 'LWR x/c = 0.0714', 'LWR x/c = 0.175', 'LWR x/c = 0.317',
              'LWR x/c = 0.510','LWR x/c = 0.698','UPPER x/c = 0.0317', 'UPPER x/c = 0.119', 'UPPER x/c = 0.230',
              'UPPER x/c = 0.413', 'UPPER x/c = 0.603', 'UPPER x/c = 0.794']

d = {'Variable': Index_six,'Manometer Reading (mm)':sixdeg}
df = pd.DataFrame(d)

df.to_csv('Six_deg.csv', index=False)

# %% [markdown]
# ### 12 degrees

# %% [markdown]
# Next with the aerofoil set to 12 degrees, turning the aerofoil clockwise will result in the upper surface as labelled in the summary table being the upper surface, if turned anti clockwise just switch lower and upper around and adjust general data cell, the lowest numbered tapping is the leading edge.  When turning the aerofoil clockwise the tappings on the left hand side will be the lower surface and therefore put them on the tappings 1-6 then upper surface will be 7 to 12.

# %%
Total_twelvedeg = 230
Static_twelvedeg =  186

#The below readings for one left hand side of the foil (if you turn the foil clockwise - this will be lower side)
twelvedeg_tapping1 = 230
twelvedeg_tapping2 = 212
twelvedeg_tapping3 = 188
twelvedeg_tapping4 = 178
twelvedeg_tapping5 = 186
twelvedeg_tapping6 = 176

#The below readings are right hand side of the foil (if you turn the foil clockwise - this will be the upper side)
twelvedeg_tapping7 = 76
twelvedeg_tapping8 = 92
twelvedeg_tapping9 = 118
twelvedeg_tapping10 = 147
twelvedeg_tapping11 = 161
twelvedeg_tapping12 = 173

twelvedeg = [Total_twelvedeg,Static_twelvedeg,twelvedeg_tapping1,twelvedeg_tapping2,twelvedeg_tapping3,
             twelvedeg_tapping4,twelvedeg_tapping5, twelvedeg_tapping6,twelvedeg_tapping7,twelvedeg_tapping8,
             twelvedeg_tapping9,twelvedeg_tapping10,twelvedeg_tapping11,twelvedeg_tapping12]
Index_Twelve = ['P_tot', 'P_static', 'LWR x/c = 0.0159', 'LWR x/c = 0.0714', 'LWR x/c = 0.175', 'LWR x/c = 0.317',
              'LWR x/c = 0.510','LWR x/c = 0.698','UPPER x/c = 0.0317', 'UPPER x/c = 0.119', 'UPPER x/c = 0.230',
              'UPPER x/c = 0.413', 'UPPER x/c = 0.603', 'UPPER x/c = 0.794']

d = {'Variable': Index_Twelve,'Manometer Reading (mm)':twelvedeg}
df = pd.DataFrame(d)

df.to_csv('Twelve_deg.csv', index=False)

# %% [markdown]
# ## More data
#
# If you have the time, please also take data for other angles of attack as this will allow us to compute the lift curve slope more accurately. You could take data for 3 degrees and 9 degrees. For this, you need to create new cells, which you can just cut and paste from above, rename them for the new angles and write the files in to appropriate filenames. That gives you 5 data points to fit a straight line for the lift curves slope.
#
# Finally, set the angle of attack of the airfoil at 20 degrees (or maybe a bit more), then observe what happens to the liquid columns of the pressure tappings.
# Do you see the columns moving around with time?
# Why do you think this happens?
#
# (observations - manometer readings from upper wing surface drop, indicating stall because the airflow has separated)

# %% [markdown]
# # THIS SECTION IS THE POST-PROCESSING OF THE DATA OBTAINED IN THE LAB EXPERIMENTS
# ## Load Data and Summary

# %% [markdown]
# The cell below reads the data files generate in the lab (Or as given on blackboard if you were unable to attend a lab) and outputs 3 tables. If you acquired data for more angles of attack, then, you need to expand the code below accordingly.

# %%
Zero_data = pd.read_csv("Zero_deg.csv")
Variable,Manometer = Zero_data.columns
Variable_Zero = Zero_data[Variable]
Manometer_Zero = Zero_data[Manometer]

Six_data = pd.read_csv("Six_deg.csv")
Variable,Manometer = Six_data.columns
Variable_Six = Six_data[Variable]
Manometer_Six = Six_data[Manometer]

Twelve_data = pd.read_csv("Twelve_deg.csv")
Variable,Manometer = Twelve_data.columns
Variable_Twelve = Twelve_data[Variable]
Manometer_Twelve = Twelve_data[Manometer]


#This is just to show the data next to each other
pd.concat([Zero_data, Six_data, Twelve_data], keys=['Zero', 'Six', 'Twelve'], axis=1)
# Out:
#                   Zero                                        Six  \
#               Variable Manometer Reading (mm)            Variable
# 0                P_tot                    235               P_tot
# 1             P_static                    183            P_static
# 2     LWR x/c = 0.0159                    206    LWR x/c = 0.0159
# 3     LWR x/c = 0.0714                    154    LWR x/c = 0.0714
# 4      LWR x/c = 0.175                    145     LWR x/c = 0.175
# 5      LWR x/c = 0.317                    149     LWR x/c = 0.317
# 6      LWR x/c = 0.510                    182     LWR x/c = 0.510
# 7      LWR x/c = 0.698                    167     LWR x/c = 0.698
# 8   UPPER x/c = 0.0317                    177  UPPER x/c = 0.0317
# 9    UPPER x/c = 0.119                    142   UPPER x/c = 0.119
# 10   UPPER x/c = 0.230                    146   UPPER x/c = 0.230
# 11   UPPER x/c = 0.413                    155   UPPER x/c = 0.413
# 12   UPPER x/c = 0.603                    163   UPPER x/c = 0.603
# 13   UPPER x/c = 0.794                    174   UPPER x/c = 0.794
#
#                                        Twelve
#    Manometer Reading (mm)            Variable Manometer Reading (mm)
# 0                     235               P_tot                    230
# 1                     183            P_static                    186
# 2                     229    LWR x/c = 0.0159                    230
# 3                     183    LWR x/c = 0.0714                    212
# 4                     163     LWR x/c = 0.175                    188
# 5                     160     LWR x/c = 0.317                    178
# 6                     185     LWR x/c = 0.510                    186
# 7                     169     LWR x/c = 0.698                    176
# 8                     138  UPPER x/c = 0.0317                     76
# 9                     119   UPPER x/c = 0.119                     92
# 10                    133   UPPER x/c = 0.230                    118
# 11                    148   UPPER x/c = 0.413                    147
# 12                    162   UPPER x/c = 0.603                    161
# 13                    173   UPPER x/c = 0.794                    173

# %% [markdown]
# ## Post Processing

# %% [markdown]
# If running this after the lab, run the above cells to load the data and to get it ready to be processed.
# <br>
#
# The first step is to define a function to find the velocity of the flow taking the total and static pressure as inputs.
#
# Following this define a function to calculate the pressure coefficent taking the velocity, static pressure at the tapping and the atmospheric pressure.
#
# Once the two above functions have been define, create a function to take the array for each angle of attack as set out above, The first 3 values can be used to calculate the velocity the flow, while the others can be used to calculate the Cp on the upper and lower surfaces. Remember that tappings 1 to 6 are the lower and 7 to 12 are the upper if you turned the aerofoil clockwise.
#
# Remember to use the x coordinate array that we made earlier for the lower and upper surfaces. These values in terms of $x/c$ is also given in the file. Split the pressures in to two lists/arrays for the lower and upper surfaces. This will make it easy to carry out the integration and also useful for plotting.
#
# The slope of the aerofoil will be needed and this can be calculated from the aerofoil equation for an aerofoil, the tapping locations can be found above on the plot and therefore the gradient can be calculated.
#
# $y_t = 5 \cdot t \cdot [0.2969 \cdot \sqrt{x} - 0.1260 \cdot x -0.3516 \cdot x^2 - 0.1015 \cdot x^4]$
#
# You can just compute the derivative analytically and then use that formula to get $dy_u/dx$ and $dy_l/dx$. This way, you can just get the values at the location of the pressure tapping.
#
# Note that in this equation all units are non-dimensionalised with respect to chord length (so x = 1 is the trailing edge of the airfoil and t is the thickness of the airfoil in terms of chord length). In order to find $C_N$ and $C_T$, you will need to integrate the pressure distribution. This can be done by using the trapezium rule or the simpson's rule.
#
# The arrays to be used in the data processing are defined in the summary and load data cell, the arrays are from Pandas data frames as introduced at the begining of this module.

# %%
# NOTES:  e = 0.95
# Need to fix values, I turned aerofoil counter clockwise
Ue = 20 #Upstream Velocity (NOT USED, CALC BELOW)
chord = 0.063 #meters
nu = .00001511 #kinematic viscosity in m^2/s
Re = Ue * chord / nu

# Define a function to calculate the Velocity
H_0 = [108, 132, 110, 120, 98, 92, 94, 100, 104, 108, 94, 94, 98, 102, 106]
H_6 = [108, 134, 110, 132, 112, 106, 104, 104, 106, 82, 78, 86, 94, 100, 106]
H_12 = [108, 134, 112, 134, 124, 114, 110, 108, 108, 60, 68, 78, 94, 100, 106]
x = [1, 2, 4.5, 7.5, 11, 14.5, 20, 26, 32.1, 38, 44, 50]
c = 63
xc = []
for i in x:
    xc.append(i/c)
rho = Pressure/(287*Temperature_kelvin)
t = 0.20

U = ((H_0[0] - H_0[1])/(-0.5 * rho) )**0.5

def pressure(h, name="P"):
    name = []
    for i in h:
        name.append(0.001*i*1000*9.81)
    return (name)
#P_atm = third value

def velocity(p, name="V"):
    name = []
    for i in p:
        name.append(((2*(p[1]-i))/rho)**0.5)
    return (name)
#Free stream velocity = third value

# Define a function to calculate the Cp
def Cp(p, U, patm, name="Cp"):
    speed = U
    name = []
    for i in p:
        name.append((i-patm)/(0.5*rho*(speed**2))) #? Added -
        #name.append((i-pinf)/ptot-pinf)
    return (name)

# Define a function to process the array
def split(a):
    first3 = []
    lower = []
    upper = []
    for i in a[0:3]:
        first3.append(i)
    for i in a[3:9]:
        lower.append(i)
    for i in a[9:]:
        upper.append(i)
    return (first3, lower, upper)
    
# Define a function to find the slope of the aerofoil
def slope(X):
    slp = []
    for i in X:
        slp.append(0.14845*(i**(-0.5))-0.126-0.7032*i-0.406*i**3)
    return (slp)

# Define a function function to find Cl by integrating the pressure coefficient
def Cl(h, X, c, alpha, U):
    meta, lower, upper = split(h)
    
    x_upper = []
    x_lower = []
    for i in xc_upper:
        x_upper.append(i*0.063)
    for i in xc_lower:
        x_lower.append(i*0.063)
        
    Pmeta = pressure(meta)
    Pupper = pressure(upper)
    Plower = pressure(lower)
    
    SlopeUpper = slope(xc_upper)
    SlopeLower = slope(xc_lower)
    
    Cpu = Cp(Pupper, U, Pmeta[2])
    Cpl = Cp(Plower, U, Pmeta[2])
    #print(Cpu)
    #print(Cpl)
    
    Cpuxdyu = np.multiply(Cpu, SlopeUpper)
    Cplxdyl = np.multiply(Cpl, SlopeLower)
    
    Cn = (1/c)*(np.trapz(Cpl, x_lower)-np.trapz(Cpu, x_upper))
    Ct = (1/c)*(np.trapz(Cpuxdyu, x_upper)-np.trapz(Cplxdyl, x_lower))
    return (Cpu, Cpl, ((Cn*np.cos(alpha*(np.pi/180)))-Ct*np.sin(alpha*(np.pi/180))))

# %% [markdown]
# In the cells below to calculate the lift coefficent of the aerofoil as well as the velocity. Then plot the pressure distribution from the data collected above (plot should follow normal convention ie negative cp on the y axis, x/c on the x-axis), it would also be good to plot the pressure distribution obtained from CFD.

# %% [markdown]
# ### 0 Degrees

# %%
# In this cell find and print the Cl and Velocity
speed0 = velocity(pressure(H_0))
U0 = speed0[2]
print("Airspeed:", U0,"m/s")
data0 = Cl(H_0, xc, 0.063, 0, U0)[0], Cl(H_0, xc, 0.063, 0, U0)[1]
print(Cl(H_0, xc, 0.063, 0, U0))
# Out:
# Airspeed: 18.868903077628573 m/s
# ([-0.09090909090909147, -0.7272727272727275, -0.7272727272727275, -0.5454545454545462, -0.36363636363636326, -0.18181818181818188], [0.4545454545454542, -0.5454545454545462, -0.8181818181818185, -0.7272727272727275, -0.45454545454545525, -0.2727272727272723], 0.005772005772005732)

# %%
# Plot the pressure distribution and also plot the CFD distribution. Remember to read in the CFD data that you wrote to file when you did the CFD simulation.

plt.plot(xc_upper, data0[0], 'C0-',label='Upper Surface')
plt.plot(xc_lower, data0[1], 'C1-',label='Lower Surface')
plt.xlabel("chord"); plt.ylabel("-Cp");plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ### 6 Degrees

# %%
# In this cell find and print the Cl and Velocity
speed6 = velocity(pressure(H_6))
U6 = speed6[2]
print("Airspeed:", U6,"m/s")
data6 = Cl(H_6, xc, 0.063, 6, U6)[0], Cl(H_6, xc, 0.063, 6, U6)[1]
print(Cl(H_6, xc, 0.063, 6, U6))

ansys6 = pd.read_csv("6deg xy.csv")
ansys6 = np.array(ansys6, dtype = np.float32)

xflr6 = pd.read_csv("Cp_Graph 6deg.csv")
xflr6 = np.array(xflr6)
# Out:
# Airspeed: 19.707926509253003 m/s
# ([-1.1666666666666679, -1.3333333333333346, -1.0000000000000009, -0.6666666666666673, -0.4166666666666676, -0.16666666666666682], [0.9166666666666671, 0.08333333333333293, -0.16666666666666682, -0.24999999999999975, -0.24999999999999975, -0.16666666666666682], 0.45854061093435405)

# %%
# Plot the pressure distribution and also plot the CFD distribution. Remember to read in the CFD data that you wrote to file when you did the CFD simulation.

plt.plot(xc_upper, data6[0], 'C0-',label='Upper Surface')
plt.plot(xc_lower, data6[1], 'C1-',label='Lower Surface')
plt.scatter(ansys6[:,0]/0.063, ansys6[:,1], label="CFD 6deg", marker = '+', c='green')
plt.scatter(xflr6[:,0], xflr6[:,1], label="XFLR5 6deg", marker = '+', c='red')
plt.xlabel("chord"); plt.ylabel("-Cp");plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ### 12 Degrees

# %%
# In this cell find and print the Cl and Velocity
speed12 = velocity(pressure(H_12))
U12 = speed12[2]
print("Airspeed:", U12,"m/s")
data12 = Cl(H_12, xc, 0.063, 12, U12)[0], Cl(H_12, xc, 0.063, 12, U12)[1]
print(Cl(H_12, xc, 0.063, 12, U12))

ansys12 = pd.read_csv("12deg xy.csv")
ansys12 = np.array(ansys12, dtype = np.float32)

xflr12 = pd.read_csv("Cp_Graph 12deg.csv")
xflr12 = np.array(xflr12)
# Out:
# Airspeed: 18.868903077628573 m/s
# ([-2.363636363636364, -2.0000000000000004, -1.5454545454545456, -0.818181818181818, -0.5454545454545456, -0.2727272727272723], [0.9999999999999999, 0.5454545454545456, 0.09090909090909147, -0.09090909090909041, -0.18181818181818188, -0.18181818181818188], 0.8267509218353443)

# %%
# Plot the pressure distribution and also plot the CFD distribution. Remember to read in the CFD data that you wrote to file when you did the CFD simulation.

plt.plot(xc_upper, data12[0], 'C0-',label='Upper Surface')
plt.plot(xc_lower, data12[1], 'C1-',label='Lower Surface')
plt.scatter(ansys12[:,0]/0.063, ansys12[:,1], label="CFD 12deg", marker = '+', c='green')
plt.scatter(xflr12[:,0], xflr12[:,1], label="XFLR5 12deg", marker = '+', c='red')
plt.xlabel("chord"); plt.ylabel("-Cp");plt.legend()
plt.gca().invert_yaxis()
plt.show()
